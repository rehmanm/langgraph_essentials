# %%
# %load_ext autoreload
# %autoreload 2

# %%
from IPython.display import Image, display
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from studio.conditional_edges import graph, State

# %%
display(Image(graph.get_graph(xray=1).draw_mermaid_png()))

# %%
initial_state = State(
    nList = ["q"]
)

graph.invoke(initial_state)
# Out:
# {'nList': ['q']}
