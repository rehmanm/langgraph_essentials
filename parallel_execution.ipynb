# %%
# %load_ext autoreload
# %autoreload 2

# %%
from IPython.display import Image, display
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from studio.parallel_execution import graph, State

# %%
display(Image(graph.get_graph(xray=1).draw_mermaid_png()))

# %%
initial_state = State(
    nList = ["Initial State"]
)

graph.invoke(initial_state)
# Out:
# Adding 'A' to ['Initial State']
# Adding 'B' to ['Initial State', 'A']
# Adding 'C' to ['Initial State', 'A']
# Adding 'BB' to ['Initial State', 'A', 'B', 'C']
# Adding 'CC' to ['Initial State', 'A', 'B', 'C']
# Adding 'D' to ['Initial State', 'A', 'B', 'C', 'BB', 'CC']
# {'nList': ['Initial State', 'A', 'B', 'C', 'BB', 'CC', 'D']}
